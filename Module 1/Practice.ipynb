# %%
1.Create a variable name and store your name. Print:"Hello, <your name>!"

# %%
name = "Minna Joby"
print(f'Hello, {name}')
# Out:
# Hello, Minna Joby

# %%
2. Create two variables: age = 21, height = 165.4.
Print their types using type().

# %%
age = 21
height = 165.4
print(type(age))
print(type(height))
# Out:
# <class 'int'>
# <class 'float'>

# %%
3. Convert height to an integer.

# %%
int(height)
# Out:
# 165

# %%
4. Write Python code to calculate the area of a triangle with base 10 and height 5.

# %%
base = 10
height = 5
area_of_triangle = (1/2)*base*height
print(area_of_triangle)
# Out:
# 25.0

# %%
5. If a laptop costs ₹50,000 and you get a discount of 18%, calculate the final price.

# %%
price = 50000
discount = 18/100
final_price = price*discount
print(final_price)
# Out:
# 9000.0

# %%
6. Replace “bad” with “good” in "Python is bad"

# %%
"Python is bad".replace('bad','good')
# Out:
# 'Python is good'

# %%
7. Ask user for age and print it as integer.

# %%
ages = int(input("Enter age:"))
print(ages)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 age = int(input("Enter age"))
#       2 print(age)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'PyodideFuture'
