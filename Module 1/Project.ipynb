# %% [markdown]
# PROJECT 1: Simple Personal Profile Generator
#
# Write a program that:
# Takes your name, age, hobby as input
# Prints a “profile card”

# %%
name = 'minna'
age = 21
hobby = 'singing'
print(f'Profile Card\nName:{name}\nAge:{age}\nHobby:{hobby}')
# Out:
# Profile Card
# Name:minna
# Age:21
# Hobby:singing

# %% [markdown]
# PROJECT 2: String Analyzer
#
# Write a program that asks the user for a string and prints:
# length
# uppercase
# lowercase
# first 3 characters
# reverse string

# %%
string = 'helloworld'
print(len(string))
print(string.upper())
print(string.lower())
print(string[:3])
print(string[::-1])
# Out:
# 10
# HELLOWORLD
# helloworld
# hel
# dlrowolleh

# %%
PROJECT 3: Basic Calculator

addition
subtraction
multiplication
division

# %%
x = 4
y = 5
print(x + y)
print(x - y)
print(x*y)
print(x/y)
print(x%y)
# Out:
# 9
# -1
# 20
# 0.8
# 4

# %%
PROJECT 4: Simple Billing System

item price
quantity
Print:
total price
GST 18%
final amount

# %%
Item_price = 25
quantity = 3
total_price = Item_price+quantity
print(total_price)
print(f"final amount:{total_price*(18/100)}")
# Out:
# 28
# final amount:5.04

# %%
PROJECT 4 — Temperature Converter

Celsius → Fahrenheit
F = (C × 9/5) + 32
